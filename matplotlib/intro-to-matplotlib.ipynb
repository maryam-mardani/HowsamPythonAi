# %% [markdown]
# # <font color='#FFE15D'>**Matplotlib**</font> 📈📊📐

# %% [markdown]
# <img src="../python/images/matplotlib.png" alt="string indexing" width=150 align="center" />

# %% [markdown]
# ## **🔶 Section 0: Import matplotlib**

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

import numpy as np

# %%
mpl.__version__
# Out:
# '3.6.3'

# %% [markdown]
# ## **🔶 Section 1: 2D plot `plt.plot()`**

# %% [markdown]
# <img src="../python/images/plot2d.png" alt="string indexing" width=550 align="center" />

# %% [markdown]
# ### Plot data points

# %%
x = np.array([78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96])
y = np.array([7,  12, 14, 16, 15, 13, 7,  8,  3,  0,  2,  11, 7,  11, 11, 12, 9,  12, 23])
plt.plot(x, y);

# %% [markdown]
# #### You may need `plt.show()`

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Plot $y=2x+1$ line

# %%
x = np.linspace(-10, 10, 100)
y = 2*x + 1

plt.plot(x, y)

# %% [markdown]
# ### Plot `sin()` function

# %%
x = np.linspace(0, 2*np.pi, 1000)
y = np.sin(x)
print(len(x))

plt.plot(x, y);
# Out:
# 1000

# %% [markdown]
# ### Many plots

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

x1 = np.linspace(0.01, 5, 50)
y3 = np.log(x1)

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x1, y3)

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

x1 = np.linspace(0.01, 5, 50)
y3 = np.log(x1)

plt.figure()
plt.plot(x, y1)
plt.plot(x1, y3)

plt.figure()
plt.plot(x, y2)

# %% [markdown]
# ## **✍️ Example: Sigmoid**

# %% [markdown]
# $$y=\sigma(x)=\frac{1}{1+\exp(-ax)}$$

# %%
def sigmoid(x, a):
    y = 1 / (1 + np.exp(-a*x))
    return y

# %%
x = np.linspace(-10, 10, 1000)
y = sigmoid(x, a=5)

plt.plot(x, y)

# %%
x = np.linspace(-10, 10, 1000)

plt.plot(x, sigmoid(x, a=0.1))
plt.plot(x, sigmoid(x, a=1))
plt.plot(x, sigmoid(x, a=2))
plt.plot(x, sigmoid(x, a=5))
plt.plot(x, sigmoid(x, a=10))

# %% [markdown]
# ## 🔶 **Section 2: Plot style**

# %% [markdown]
# <img src="../python/images/plot-style.png" alt="string indexing" width=500 align="center" />

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %% [markdown]
# ### Color

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
x = np.linspace(0, 10, 10)

plt.plot(x, x + 0, color='r') 
plt.plot(x, x + 1, color='blue')
plt.plot(x, x + 2, color=(1, 0, 0, 0.5)) #RGB
plt.plot(x, x + 3, color='#f0e9c4')

# %% [markdown]
# ### Line style

# %% [markdown]
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html

# %%
plt.plot(x, x + 0, linestyle='solid') 
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted')

# %% [markdown]
# #### Shortcut

# %%
plt.plot(x, x + 0, linestyle='-') 
plt.plot(x, x + 1, linestyle='--')
plt.plot(x, x + 2, linestyle='-.')
plt.plot(x, x + 3, linestyle=':')

# %% [markdown]
# #### Thickness

# %%
plt.plot(x, x + 0, linewidth=5)
plt.plot(x, x + 1, linewidth=10.5)
plt.plot(x, x + 2, linewidth=0.5)
plt.plot(x, x + 3, linewidth=1.5)

# %% [markdown]
# ### Marker

# %% [markdown]
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/marker_reference.html

# %%
plt.plot(x, x + 0, marker='4', markersize=10) 
plt.plot(x, x + 1, marker='*')
plt.plot(x, x + 2, marker='o')
plt.plot(x, x + 3, marker='s', markersize=10, markerfacecolor='w')

# %% [markdown]
# ### All-in-one!

# %%
plt.plot(x, x + 0, color='r', linestyle='-', marker='*') 
plt.plot(x, x + 1, color='b', linestyle='--', marker='s')
plt.plot(x, x + 2, color='g', linestyle='-.', marker='2')
plt.plot(x, x + 3, color='k', linestyle=':', marker='o')

# %%
x = np.linspace(0, 10, 10)

plt.plot(x, x + 0, '*-r') 
plt.plot(x, x + 1, 's--b')
plt.plot(x, x + 2, '2-.g')
plt.plot(x, x + 3, 'o:k', linewidth=2)

# %%
plt.plot(x, x, '*-r', x, x + 1, 's--b', x, x + 2, '2-.g', x, x + 3, 'o:k');

# %%
xt = np.vstack((x, x, x, x)).transpose()
yt = np.vstack((x, x+1, x+2, x+3)).transpose()
print(xt.shape, yt.shape)

plt.plot(xt, yt);
# Out:
# (10, 4) (10, 4)

# %% [markdown]
# ## 🔶 **Section 3: Title**

# %% [markdown]
# <img src="../python/images/title.png" alt="string indexing" width=500 align="center" />

# %% [markdown]
# ### `plt.title()`

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.title('sin(x)', loc='center', fontsize=15, color='red', fontfamily='serif');

# %%
x = np.linspace(0, 10, 100)
alpha = 2
plt.plot(x, np.sin(x+alpha))

fontdict={'family':'serif', 'size':15, 'color':'r'}
plt.title(f'function: $sin(x_i + {alpha})$', loc='center', fontdict=fontdict);

# %% [markdown]
# ### `plt.xlabel()` & `plt.ylabel()`

# %%
x = np.linspace(0, 10, 100)
alpha = 2
plt.plot(x, np.sin(x+alpha))

fontdict={'family':'serif', 'size':15, 'color':'r'}
plt.title(f'function: $sin(x_i + {alpha})$', loc='center', fontdict=fontdict)

plt.xlabel('$x$', fontdict=fontdict, loc='right')
plt.ylabel('$y$', fontdict=fontdict, loc='top');

# %% [markdown]
# ### `plt.legend()`

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x), label='sin')
plt.plot(x, np.cos(x), label='cos')

plt.legend(loc='center')

# %% [markdown]
# ## 🔶 **Section 4: Axis**

# %% [markdown]
# <img src="../python/images/axis.png" alt="string indexing" width=500 align="center" />

# %% [markdown]
# ### Axes limits

# %% [markdown]
# #### `plt.xlim()` and `plt.ylim()`

# %%
x = npi.lnspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.xlim(0, 5)
plt.ylim(0, 1.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 x = npi.lnspace(0, 10, 100)
#       2 plt.plot(x, np.sin(x))
#       3 plt.xlim(0, 5)
#
# NameError: name 'npi' is not defined

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
xs, xe = plt.xlim()
xs, xe

# %% [markdown]
# #### `plt.axis()`

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.axis([0, 5, -1, 0]);
xs, xe, ys, ye = plt.axis()

# %% [markdown]
# ### Add grid to a plot

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.grid(axis='y')

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.grid(which='major')
plt.grid(which='minor', linestyle=':', color='k', alpha=0.2)
plt.minorticks_on()

# %% [markdown]
# ## **✍️ Example: Unhealthy days in Tehran**

# %% [markdown]
# <img src="../python/images/plot2d.png" alt="string indexing" width=550 align="center" />

# %%
x = np.array([78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96]) + 1300
y = np.array([7,  12, 14, 16, 15, 13, 7,  8,  3,  0,  2,  11, 7,  11, 11, 12, 9,  12, 23])
plt.plot(x, y, linewidth=3, marker='o', markersize=8, mfc='w')
plt.xlim(1378, 1396)
plt.ylim(0, 30)
plt.grid(axis='y', alpha=0.3)
plt.title('مقایسه تعداد روزهای ناسالم در آبان ماه‌های 20 سال اخیر در تهران')

# %% [markdown]
# ## **🔶 Section 5: Scatter plot**

# %% [markdown]
# <img src="../python/images/scatter.png" alt="string indexing" width=500 align="center" />

# %%
np.random.seed(0)
x = np.random.randn(100)
y = np.random.randn(100)

# %% [markdown]
# ### Plot dots

# %%
plt.scatter(x, y)

# %% [markdown]
# #### plot dots with `plt.plot()`

# %%
plt.plot(x, y, marker='o', linestyle='none')

# %% [markdown]
# ### Change marker style

# %%
plt.scatter(x, y, marker='+')

# %%
plt.scatter(x[:50], y[:50], marker='+')
plt.scatter(x[50:], y[50:], marker='.')

# %% [markdown]
# ### Change marker size

# %%
plt.scatter(x, y, marker='2', s=50)

# %% [markdown]
# #### Samples with different sizes

# %%
sizes = np.random.randint(1, 100, size=len(x))
plt.scatter(x, y, marker='o', s=sizes)

# %% [markdown]
# ### Change marker color

# %%
plt.scatter(x, y, c='r')

# %% [markdown]
# #### Samples with different colors

# %%
plt.scatter(x[:4], y[:4], c=['r', 'g', 'k', 'b'])

# %%
colors = np.random.rand(len(x), 3)
plt.scatter(x, y, c=colors, s=sizes)
# plt.grid()

# %%
b = np.array([[0, 0, 1.]])
r = np.array([[1, 0, 0.]])

b = b.repeat(50, axis=0)
r = r.repeat(50, axis=0)
colors = np.vstack((b, r))

plt.scatter(x, y, c=colors)

# %%
colors = list(30*'r' + 40*'b' + 20*'g' + 10*'k')

plt.scatter(x, y, c=colors)

# %% [markdown]
# ## **✍️ Example: Plot gaussian with scatter**

# %% [markdown]
# <img src="../python/images/scatter-example.png" alt="string indexing" width=400 align="center" />

# %%
xyb = np.random.randn(1000, 2)
plt.scatter(xyb[:, 0], xyb[:, 1], c='b', edgecolor='w', label='$N(\mu=0, \sigma=1)$')

xyr = 0.5*np.random.randn(1000, 2) + 2
plt.scatter(xyr[:, 0], xyr[:, 1], c='r', edgecolor='w', label='$N(\mu=2, \sigma=0.5)$')

plt.title('Gaussian')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(alpha=0.2)
plt.grid(which='minor', linestyle=':', alpha=0.2)
plt.minorticks_on()
plt.legend();

# %% [markdown]
# ## **🔶 Section 6: Bar plot**

# %% [markdown]
# <img src="../python/images/bar.png" alt="string indexing" width=600 align="center" />

# %% [markdown]
# ### How to plot a bar graph

# %%
x1 = [78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96]
y1 = [7,  12, 14, 16, 15, 13, 7,  8,  3,  0,  2,  11, 7,  11, 11, 12, 9,  12, 23]

plt.bar(x1, y1)

# %%
cities = ('Tehran', 'Guilan', 'Isfahan', 'Ilam')
populations = [-13.2, -3.5, -5.1, -0.5]

plt.bar(cities, populations);

# %% [markdown]
# ### Change bar color

# %%
plt.bar(x1, y1, color='#eedd62')

# %% [markdown]
# #### Samples with differect colors

# %%
plt.bar(cities, populations, color=['r', 'b', 'g', 'k'])

# %% [markdown]
# ### Change bar width

# %%
plt.bar(x1, y1, width=0.5)

# %% [markdown]
# ### More on bars!

# %% [markdown]
# #### You can still have facecolor, edgecolor, etc.

# %%
plt.bar(x1, y1, width=1.5, facecolor='r', edgecolor='b', linewidth=1.2, alpha=0.5)

# %% [markdown]
# #### Plot multiple bar charts

# %%
x1 = np.array([78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96])

y1 = np.array([7,  12, 14, 16, 15, 13, 7,  8,  3,  0,  2,  11, 7,  11, 11, 12, 9,  12, 23])
y2 = np.array([9,  10, 18, 5, 3, 4, 0,  2,  3,  4,  1,  6, 8,  9, 10, 5, 7,  11, 6])

plt.bar(x1, y1)
plt.bar(x1, y2, color='r', alpha=0.5)

# %%
x1 = np.array([78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96])

y1 = np.array([7,  12, 14, 16, 15, 13, 7,  8,  3,  0,  2,  11, 7,  11, 11, 12, 9,  12, 23])
y2 = np.array([9,  10, 18, 5, 3, 4, 0,  2,  3,  4,  1,  6, 8,  9, 10, 5, 7,  11, 6])

w = 0.4
plt.bar(x1, y1, width=w)
plt.bar(x1-w, y2, width=w)
plt.xticks(ticks=np.arange(78, 97)-w/2, labels=np.arange(78, 97));

# %% [markdown]
# stackoverflow: https://stackoverflow.com/questions/14270391/python-matplotlib-multiple-bars

# %% [markdown]
# ## **✍️ Example: Plot `x` with bar plot**

# %%
x = np.random.randint(10, size=(100,))
x

# %%
hist, bins = np.histogram(x)
plt.bar(range(10), hist)

# %% [markdown]
# ## **🔶 Section 7: Histogram**

# %% [markdown]
# <img src="../python/images/histogram.png" alt="string indexing" width=500 align="center" />

# %% [markdown]
# ### How to plot histogram

# %%
x = np.random.randint(10, size=(100,))
counts, bin_edges = plt.hist(x)
plt.hist(x);
# Out:
# (array([ 9., 14., 12.,  9.,  4., 11.,  6., 12., 11., 12.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Working with `plt.hist()` arguments

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

# %%
plt.hist(x1, bins=40, alpha=0.3, color='g')
plt.hist(x2, bins=40, alpha=0.3, color='b')
plt.hist(x3, bins=40, alpha=0.3, color='r');

# %%
kwargs = dict(histtype='step', alpha=0.3, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# ## **✍️ Example: Plot the histogram of house prices**

# %% [markdown]
# <img src="../python/images/housesbanner.png" alt="string indexing" width=800 align="center" />

# %% [markdown]
# https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques

# %%
import pandas as pd
x = pd.read_csv('../assests/data/train.csv')['SalePrice'].values
plt.hist(x, bins=100);

# %% [markdown]
# ### `LotArea`, `OverallQual`, and `YearRemodAdd`

# %% [markdown]
# ## **🔶 Section 8: Subplot**

# %% [markdown]
# <img src="../assets/images/mosaic.png" alt="string indexing" width=450 align="center"/>

# %% [markdown]
# ### Create a grid of subplots

# %%
x = np.linspace(0, 10, 100)

# first panel
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))

# second panel
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_18172\1910421638.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 1, 1)

# %% [markdown]
# ### labels, title, legend and axis limits for each subplot

# %%
x = np.linspace(0, 10, 100)

# first panel
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");
plt.legend(['sin'])

# second panel
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %% [markdown]
# ### Mosaic

# %%
x = np.linspace(0, 10, 100)

plt.subplot(3, 1, 1)

plt.subplot(3, 3, 7)

plt.subplot(3, 3, 9)

plt.subplot(3, 2, 3)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## **✍️ Example:**

# %% [markdown]
# ## **🔶 Section 9: More on Figure**

# %% [markdown]
# ### Figure

# %% [markdown]
# #### `num`

# %%
plt.figure(num=1)
plt.plot(np.linspace(-5, 5, 100)**2)

plt.figure(num=2)
plt.plot(np.linspace(-5, 5, 100)**3)

plt.figure(num=1)
plt.plot(np.linspace(-5, 5, 100)**3)

# %% [markdown]
# #### `figsize`

# %%
plt.figure(figsize=(5, 2))
plt.plot(np.linspace(-5, 5, 100)**2)

# %% [markdown]
# #### `dpi`

# %%
plt.figure(dpi=300)
plt.plot(np.linspace(-5, 5, 100)**2)

# %% [markdown]
# #### `facecolor`

# %%
plt.figure(facecolor='red')
plt.plot(np.linspace(-5, 5, 100)**2)

# %% [markdown]
# ### Axes

# %% [markdown]
# <img src="../assets/images/figure-axes.png" alt="string indexing" width=350 align="center" />

# %%
plt.figure(figsize=(4, 3), facecolor='y')
plt.axes(facecolor='green');

# %% [markdown]
# ### Save figure

# %%
plt.figure(facecolor='red')
plt.plot(range(10))
plt.savefig('my_figure1.png', transparent=True)

# %% [markdown]
# ### Figure style

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('ggplot')
plt.plot(range(10))

# %% [markdown]
# ## **✍️ Example:**

# %% [markdown]
# ## **🔶 Section 10: Object Oriented (OO) Style 🔥**

# %% [markdown]
# <img src="../assets/images/axes.png" alt="string indexing" width=550 align="center"/>

# %% [markdown]
# https://towardsdatascience.com/the-many-ways-to-call-axes-in-matplotlib-2667a7b06e06

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot([1, 2, 3.])

# %% [markdown]
# ### The alternative ways!

# %%
fig, ax = plt.subplots(1)
ax.plot([1, 2, 3.])

# %%
fig = plt.figure()
ax = fig.add_axes()

x = np.linspace(0, 10, 100)
y = np.sin(x)

# %% [markdown]
# ### Plots

# %% [markdown]
# #### `ax.plot()`

# %% [markdown]
# <img src="../assests/images/matlabstyle-to-oo.png" alt="string indexing" width=300 align="center" />

# %%
ax = plt.axes()
print(ax)

x = np.linspace(0, 10, 100)
y = np.sin(x)

ax.plot(x, y)

ax.set_xlabel('x')
ax.set_ylabel('sin(x)')
ax.set_xlim(2, 5)
ax.set_ylim(-2, 2)
ax.set_title('Sine')
# ax.axis([2, 5, -2, 2])
ax.grid();
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %% [markdown]
# #### Set the labels, title and limits in one line!

# %%
ax = plt.axes()
ax.plot(x, y)

ax.set(xlabel ='x', ylabel ='sin(x)',
       xlim =(0, 1.5), ylim =(0.5, 1.5),
       title ='Sine');

# %% [markdown]
# #### `ax.scatter()`

# %%
ax = plt.axes()

x = np.random.randn(100)
y = np.random.randn(100)

colors = np.r_[np.ones(50), np.zeros(50)]
sizes = np.r_[50*np.ones(50), 200*np.ones(50)]

ax.scatter(x, y, c=colors, s=sizes, marker='*');

# %% [markdown]
# #### `ax.bar()`

# %%
ax = plt.axes()

populations = [13.2, 3.5, 5.1, 0.5]
cities = ('Tehran', 'Gilan', 'Isfahan', 'Ilam')

ax.bar(cities, populations, color='r')
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# #### `ax.hist()`

# %%
ax = plt.axes()

height = np.random.randint(50, 210, size=100)
ax.hist(height, bins=10);

# %% [markdown]
# ### Mosaic

# %%
fig = plt.figure()
gs = plt.GridSpec(3, 3, figure=fig)

ax1 = fig.add_subplot(gs[0, :])
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = np.concatenate((np.ones(50), np.zeros(50)))
sizes = np.concatenate((50*np.ones(50), 200*np.ones(50)))
ax1.scatter(x, y, c=colors, s=sizes, marker='*')

ax2 = fig.add_subplot(gs[1, :-1])
populations = [13.2, 3.5, 5.1, 0.5]
cities = ('Tehran', 'Gilan', 'Isfahan', 'Ilam')
ax2.bar(cities, populations, color='r')

ax3 = fig.add_subplot(gs[1:, -1])
height = np.random.randint(50, 210, size=100)
ax3.hist(height, bins=10)

ax4 = fig.add_subplot(gs[-1, 0])
ax4.plot(x, x*x*x)

ax5 = fig.add_subplot(gs[-1, -2])
plt.tight_layout(pad=1.2)
plt.show()

# %% [markdown]
# ## **✍️ Example:**

# %% [markdown]
# ## **🔶 Section 11: 3D**

# %% [markdown]
# ### `plot3D()`

# %%
t = np.linspace(0, 20, 100)
x = np.sin(t)
y = np.cos(t)

ax = plt.axes(projection='3d')
ax.plot3D(x, y, t)

# %%
t = np.linspace(0, 20, 100)
x = np.sin(t)
y = np.cos(t)
z1 = t
z2 = t**2

ax = plt.axes(projection='3d')
ax.plot3D(x, y, z1, 'b-', label='Line 1')
ax.plot3D(x, y, z2, 'r-', label='Line 2')

# %% [markdown]
# ### `scatter3D()`

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 60)
y = np.linspace(-6, 6, 60)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

ax = plt.axes(projection='3d')
ax.scatter3D(X, Y, Z)

# %% [markdown]
# ### `plot_surface()`

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z)

# %% [markdown]
# ### 3D plot style

# %% [markdown]
# #### ↳ Title, label, and etc.

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f')

ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_ylim(-10, 10)

ax.set_title('sine')

# %% [markdown]
# #### ↳ Face color

# %% [markdown]
# #### ↳ Edge color

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='Pastel1', edgecolor='k')

# %% [markdown]
# #### ↳ Colormap

# %% [markdown]
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='Pastel1')
